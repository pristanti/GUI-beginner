# %% [markdown]
# <a href="https://colab.research.google.com/github/pristanti/GUI-beginner/blob/master/Go_Play_Take_home_aasignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade gspread
# Out:
# ...
#   Found existing installation: gspread 3.0.1
#     Uninstalling gspread-3.0.1:
#       Successfully uninstalled gspread-3.0.1
# ...

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())

worksheet = gc.open('Go Play - Assignment').sheet1

# %%
# get_all_values gives a list of rows.
rows = worksheet.get_all_values()
print(rows)
# Out:
# [['Date', 'Month', '# of Orders', 'Status of Order', 'Total CBV', 'Service'], ['01/01/16', '1', '180', 'Cancelled', '76.076.000', 'GO-BOX'], ['01/01/16', '1', '10', 'Cancelled', '1.960.140', 'GO-CLEAN'], ['01/01/16', '1', '28380', 'Cancelled', '489.898.500', 'GO-FOOD'], ['01/01/16', '1', '0', 'Cancelled', '728', 'GO-GLAM'], ['01/01/16', '1', '10', 'Cancelled', '136.5', 'GO-KILAT'], ['01/01/16', '1', '1710', 'Cancelled', '23.933.000', 'GO-MART'], ['01/01/16', '1', '80', 'Cancelled', '14.714.700', 'GO-MASSAGE'], ['01/01/16', '1', '33230', 'Cancelled', '855.767.640', 'GO-RIDE'], ['01/01/16', '1', '1760', 'Cancelled', '66.238.900', 'GO-SEND'], ['01/01/16', '1', '9280', 'Cancelled', '236.874.820', 'GO-SHOP'], ['01/01/16', '1', '160', 'Cancelled', '-', 'GO-TIX'], ['01/01/16', '1', '470', 'Completed', '193.458.265', 'GO-BOX'], ['01/01/16', '1', '110', 'Completed', '17.510.220', 'GO-CLEAN'], ['01/01/16', '1', '66390', 'Completed', '1.114.831.900', 'GO-FOOD'], ['01/01/16', '1', '60', 'Complet
# ...

# %%
# Convert to a DataFrame and render.
import pandas as pd
tableA = pd.DataFrame.from_records(rows, columns=rows[0])
tableA.drop(index=0, axis=1, inplace=True)
tableA.head(10)
# Out:
#         Date Month # of Orders Status of Order    Total CBV     Service
# 1   01/01/16     1         180       Cancelled   76.076.000      GO-BOX
# 2   01/01/16     1          10       Cancelled    1.960.140    GO-CLEAN
# 3   01/01/16     1       28380       Cancelled  489.898.500     GO-FOOD
# 4   01/01/16     1           0       Cancelled          728     GO-GLAM
# 5   01/01/16     1          10       Cancelled        136.5    GO-KILAT
# 6   01/01/16     1        1710       Cancelled   23.933.000     GO-MART
# 7   01/01/16     1          80       Cancelled   14.714.700  GO-MASSAGE
# 8   01/01/16     1       33230       Cancelled  855.767.640     GO-RIDE
# 9   01/01/16     1        1760       Cancelled   66.238.900     GO-SEND
# 10  01/01/16     1        9280       Cancelled  236.874.820     GO-SHOP

# %%
tableA["Total CBV"] = tableA["Total CBV"].str.replace("-", "0")
tableA.head(12)
# Out:
#         Date Month # of Orders Status of Order    Total CBV     Service
# 1   01/01/16     1         180       Cancelled   76.076.000      GO-BOX
# 2   01/01/16     1          10       Cancelled    1.960.140    GO-CLEAN
# 3   01/01/16     1       28380       Cancelled  489.898.500     GO-FOOD
# 4   01/01/16     1           0       Cancelled          728     GO-GLAM
# 5   01/01/16     1          10       Cancelled        136.5    GO-KILAT
# 6   01/01/16     1        1710       Cancelled   23.933.000     GO-MART
# 7   01/01/16     1          80       Cancelled   14.714.700  GO-MASSAGE
# 8   01/01/16     1       33230       Cancelled  855.767.640     GO-RIDE
# 9   01/01/16     1        1760       Cancelled   66.238.900     GO-SEND
# 10  01/01/16     1        9280       Cancelled  236.874.820     GO-SHOP
# 11  01/01/16     1         160       Cancelled            0      GO-TIX
# 12  01/01/16     1         470       Completed  193.458.265      GO-BOX

# %%
# create, and save df
from gspread_dataframe import set_with_dataframe
title = 'Go Play - Assignment-2'
gc.create(title)
sheet = gc.open(title).sheet1
set_with_dataframe(sheet, tableA) 
tableA
# Out:
#           Date Month # of Orders  Status of Order    Total CBV     Service
# 1     01/01/16     1         180        Cancelled   76.076.000      GO-BOX
# 2     01/01/16     1          10        Cancelled    1.960.140    GO-CLEAN
# 3     01/01/16     1       28380        Cancelled  489.898.500     GO-FOOD
# 4     01/01/16     1           0        Cancelled          728     GO-GLAM
# 5     01/01/16     1          10        Cancelled        136.5    GO-KILAT
# ...        ...   ...         ...              ...          ...         ...
# 3167  31/03/16     3        1870  No Driver Found   71.449.560     GO-SEND
# 3168  31/03/16     3         120  No Driver Found    5.418.140     GO-SHOP
# 3169  31/03/16     3           0            Other        555.1  GO-MASSAGE
# 3170  31/03/16     3           0            Other        49.14     GO-RIDE
# 3171  31/03/16     3           0            Other         18.2      GO-TIX
#
# [3171 rows x 6 columns]
